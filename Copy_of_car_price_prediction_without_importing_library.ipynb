# %% [markdown]
# <a href="https://colab.research.google.com/github/Mechprasad48/Astrologer-s-Stars/blob/main/Copy_of_car_price_prediction_without_importing_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Start with importing necessary library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Data wrangling

# %%
df = pd.read_csv('car data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.describe()

# %% [markdown]
# Independent variable

# %%
x = (df[['Present_Price']])

# %% [markdown]
# Dependent variable

# %%
y = df.Selling_Price

# %%
plt.scatter(x,y)

# %% [markdown]
# SSXX = Σ(x̄ -  x2)2

# %%
x_mean = x.mean()
x_mean
# Out:
# Present_Price    7.628472
# dtype: float64

# %%
df['Diffx'] = x_mean - x
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner     Diffx
# 0        Dealer       Manual      0  2.038472
# 1        Dealer       Manual      0 -1.911528
# 2        Dealer       Manual      0 -2.221528
# 3        Dealer       Manual      0  3.478472
# 4        Dealer       Manual      0  0.758472
# ..          ...          ...    ...       ...
# 296      Dealer       Manual      0 -3.971528
# 297      Dealer       Manual      0  1.728472
# 298      Dealer       Manual      0 -3.371528
# 299      Dealer       Manual      0 -4.871528
# 300      Dealer       Manual      0  1.728472
#
# [301 rows x 10 columns]

# %%
df['Diffxsquare'] = df.Diffx ** 2 
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner     Diffx  Diffxsquare
# 0        Dealer       Manual      0  2.038472     4.155367
# 1        Dealer       Manual      0 -1.911528     3.653940
# 2        Dealer       Manual      0 -2.221528     4.935188
# 3        Dealer       Manual      0  3.478472    12.099766
# 4        Dealer       Manual      0  0.758472     0.575279
# ..          ...          ...    ...       ...          ...
# 296      Dealer       Manual      0 -3.971528    15.773037
# 297      Dealer       Manual      0  1.728472     2.987615
# 298      Dealer       Manual      0 -3.371528    11.367203
# 299      Dealer       Manual      0 -4.871528    23.731787
# 300      Dealer       Manual      0  1.728472     2.987615
#
# [301 rows x 11 columns]

# %%
SSxx = df.Diffxsquare.sum()

# %% [markdown]
# SSXX = Σ(Y - y2)2

# %%
y_mean = y.mean()
y_mean
# Out:
# 4.661295681063127

# %%
df['diffy'] = y_mean - y
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner     Diffx  Diffxsquare     diffy
# 0        Dealer       Manual      0  2.038472     4.155367  1.311296
# 1        Dealer       Manual      0 -1.911528     3.653940 -0.088704
# 2        Dealer       Manual      0 -2.221528     4.935188 -2.588704
# 3        Dealer       Manual      0  3.478472    12.099766  1.811296
# 4        Dealer       Manual      0  0.758472     0.575279  0.061296
# ..          ...          ...    ...       ...          ...       ...
# 296      Dealer       Manual      0 -3.971528    15.773037 -4.838704
# 297      Dealer       Manual      0  1.728472     2.987615  0.661296
# 298      Dealer       Manual      0 -3.371528    11.367203  1.311296
# 299      Dealer       Manual      0 -4.871528    23.731787 -6.838704
# 300      Dealer       Manual      0  1.728472     2.987615 -0.638704
#
# [301 rows x 12 columns]

# %%
df['Diffysquare'] = df.diffy ** 2 
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner     Diffx  Diffxsquare     diffy  \
# 0        Dealer       Manual      0  2.038472     4.155367  1.311296
# 1        Dealer       Manual      0 -1.911528     3.653940 -0.088704
# 2        Dealer       Manual      0 -2.221528     4.935188 -2.588704
# 3        Dealer       Manual      0  3.478472    12.099766  1.811296
# 4        Dealer       Manual      0  0.758472     0.575279  0.061296
# ..          ...          ...    ...       ...          ...       ...
# 296      Dealer       Manual      0 -3.971528    15.773037 -4.838704
# 297      Dealer       Manual      0  1.728472     2.987615  0.661296
# 298      Dealer       Manual      0 -3.371528    11.367203  1.311296
# 299      Dealer       Manual      0 -4.871528    23.731787 -6.838704
# 300      Dealer       Manual      0  1.728472     2.987615 -0.638704
#
#      Diffysquare
# 0       1.719496
# 1       0.007868
# 2       6.701390
# 3       3.280792
# 4       0.003757
# ..           ...
# 296    23.413059
# 297     0.437312
# 298     1.719496
# 299    46.767877
# 300     0.407943
#
# [301 rows x 13 columns]

# %%
SSxy = df.Diffysquare.sum()

# %%
m = SSxy / SSxx
m
# Out:
# 0.34575375456097074

# %% [markdown]
# Intercept

# %%
b = y_mean - m * x_mean
b
# Out:
# Present_Price    2.023723
# dtype: float64

# %%
def predict(value):
  predict = m*value+b
  return predict

# %%
predict(9.54)
